# %% [markdown]
# <a href="https://colab.research.google.com/github/aliasgarsogiawala/Fake-News-Detector/blob/main/FakeNews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

print("A Project by Aliasgar Sogiawala")
# Out:
# A Project by Aliasgar Sogiawala

# %%
true = pd.read_csv('True.csv')

# %%
fake= pd.read_csv('Fake.csv')

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['label']=1

# %%
fake['label']=0

# %%
news= pd.concat([fake,true],axis=0)

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date  label
# 21412  August 22, 2017       1
# 21413  August 22, 2017       1
# 21414  August 22, 2017       1
# 21415  August 22, 2017       1
# 21416  August 22, 2017       1

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news = news.drop(['title','subject','date'],axis=1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0

# %%
news = news.sample(frac=1) #reshuffle the data

# %%
news.head()
# Out:
#                                                     text  label
# 21190  EDINBURGH (Reuters) - British outsourcer G4S h...      1
# 9058   A longtime Republican Party donor based in Flo...      0
# 11606  Notice how the left is still pushing the false...      0
# 5951   A new report reveals that Donald Trump swindle...      0
# 7846   WASHINGTON (Reuters) - A U.S. lawmaker urged t...      1

# %%
news.reset_index(inplace=True)

# %%
news.head()
# Out:
#    index                                               text  label
# 0  21190  EDINBURGH (Reuters) - British outsourcer G4S h...      1
# 1   9058  A longtime Republican Party donor based in Flo...      0
# 2  11606  Notice how the left is still pushing the false...      0
# 3   5951  A new report reveals that Donald Trump swindle...      0
# 4   7846  WASHINGTON (Reuters) - A U.S. lawmaker urged t...      1

# %%
news.drop(['index'],axis=1, inplace=True)

# %%
news.head()
# Out:
#                                                 text  label
# 0  EDINBURGH (Reuters) - British outsourcer G4S h...      1
# 1  A longtime Republican Party donor based in Flo...      0
# 2  Notice how the left is still pushing the false...      0
# 3  A new report reveals that Donald Trump swindle...      0
# 4  WASHINGTON (Reuters) - A U.S. lawmaker urged t...      1

# %%
import re

# %%
def wordopt(text):
  #convert to lowercase
  text= text.lower()

  #remove URLs
  text = re.sub(r'https?://\S+|www\.\S+','',text)

  #Remove HTML tags
  text = re.sub(r'<.*?>','',text)

  #Remove punctuations
  text=re.sub(r'[^\w\s]','',text)

  #Remove digits
  text=re.sub(r'\d+','',text)

  #Remove newline characters
  text=re.sub(r'\n','',text)

  return text

# %%
news['text']= news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0        edinburgh reuters  british outsourcer gs has s...
# 1        a longtime republican party donor based in flo...
# 2        notice how the left is still pushing the false...
# 3        a new report reveals that donald trump swindle...
# 4        washington reuters  a us lawmaker urged the ob...
#                                ...
# 44893    washington reuters  the united states suggeste...
# 44894    when did white students become throw away citi...
# 44895    beirut reuters  an air raid in the governmenth...
# 44896    the following statements were posted to the ve...
# 44897    honolulu reuters  president barack obama on th...
# Name: text, Length: 44898, dtype: object

# %%
x= news['text']
y=news['label']

# %%
x
# Out:
# 0        edinburgh reuters  british outsourcer gs has s...
# 1        a longtime republican party donor based in flo...
# 2        notice how the left is still pushing the false...
# 3        a new report reveals that donald trump swindle...
# 4        washington reuters  a us lawmaker urged the ob...
#                                ...
# 44893    washington reuters  the united states suggeste...
# 44894    when did white students become throw away citi...
# 44895    beirut reuters  an air raid in the governmenth...
# 44896    the following statements were posted to the ve...
# 44897    honolulu reuters  president barack obama on th...
# Name: text, Length: 44898, dtype: object

# %%
y
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 44893    1
# 44894    0
# 44895    1
# 44896    1
# 44897    1
# Name: label, Length: 44898, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test , y_train , y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorization = TfidfVectorizer()

# %%
xv_train = vectorization.fit_transform(x_train)
xv_test = vectorization.transform(x_test)

# %%
xv_train
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 6453992 stored elements and shape (31428, 174530)>

# %%
xv_test
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 2725993 stored elements and shape (13470, 174530)>

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
LR.fit(xv_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test,y_test)
# Out:
# 0.9867112100965107

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      7019
#            1       0.98      0.99      0.99      6451
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470
